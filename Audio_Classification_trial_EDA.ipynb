# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\deepak\python3\lib\site-packages (0.8.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\deepak\appdata\roaming\python\python38\site-packages (from librosa) (1.4.1)
# Requirement already satisfied: numba>=0.43.0 in c:\users\deepak\python3\lib\site-packages (from librosa) (0.51.2)
# Requirement already satisfied: audioread>=2.0.0 in c:\users\deepak\python3\lib\site-packages (from librosa) (2.1.9)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\deepak\appdata\roaming\python\python38\site-packages (from librosa) (1.20.2)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\deepak\python3\lib\site-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.9.0 in c:\users\deepak\python3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\deepak\python3\lib\site-packages (from librosa) (0.23.2)
# Requirement already satisfied: pooch>=1.0 in c:\users\deepak\python3\lib\site-packages (from librosa) (1.3.0)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\deepak\python3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\deepak\python3\lib\site-packages (from librosa) (0.17.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in c:\users\deepak\python3\lib\site-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: setuptools in c:\users\deepak\appdata\roaming\python\python38\site-packages (from numba>=0.43.0->librosa) (54.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\deepak\python3\lib\site-packages (from soundfile>=0.9.0->librosa) (1.14.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\deepak\python3\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.1.0)
# Requirement already satisfied: requests in c:\users\deepak\appdata\roaming\python\python38\site-packages (from pooch>=1.0->librosa) (2.25.1)
# Requirement already satisfied: packaging in c:\users\deepak\python3\lib\site-packages (from pooch>=1.0->librosa) (20.4)
# Requirement already satisfied: appdirs in c:\users\deepak\python3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: six>=1.3 in c:\users\deepak\appdata\roaming\python\python38\site-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\deepak\python3\lib\site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepak\appdata\roaming\python\python38\site-packages (from requests->pooch>=1.0->librosa) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\deepak\appdata\roaming\python\python38\site-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\deepak\appdata\roaming\python\python38\site-packages (from requests->pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\deepak\appdata\roaming\python\python38\site-packages (from requests->pooch>=1.0->librosa) (1.26.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\deepak\python3\lib\site-packages (from packaging->pooch>=1.0->librosa) (2.4.7)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename='C:/Users/Deepak/Data Science projects/AUDIO CLASSIFICATION PROJECT/Audio Classification Project files_Trial/1.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
plt.figure(figsize=(14,5))
data,sample_rate = librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav 
wave_sample_rate, wave_audio= wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[1556, 1556],
#        [1964, 1964],
#        [1722, 1722],
#        ...,
#        [   1,    1],
#        [   0,    0],
#        [   2,    2]], dtype=int16)

# %%
#Librosa basically normalizes the audio file which generally won't be in a normalized form
#Librosa also converts the audio file which we are using into a mono signal(eventhough the input is a stereo file)
data
# Out:
# array([ 3.8459033e-02,  5.9552170e-02,  5.1253099e-02, ...,
#        -3.5394205e-05, -2.3769824e-05,  3.0676751e-05], dtype=float32)

# %%
import pandas as pd 
metadata = pd.read_csv('C:/Users/Deepak/Data Science projects/AUDIO CLASSIFICATION PROJECT/Audio Classification Project files_Trial/sound_metadata.csv')
metadata.head(10)
# Out:
#    file_name  folder     class
# 0          6       1      Akon
# 1          7       1      Akon
# 2          8       1      Akon
# 3         11       2    Arijit
# 4         12       2    Arijit
# 5          9       3     Bruno
# 6         10       3     Bruno
# 7         13       4  ColdPlay
# 8         14       4  ColdPlay
# 9         15       4  ColdPlay

# %%
#Check whether the dataset is imbalanced
metadata['class'].value_counts()
# Out:
# Deepak        5
# ColdPlay      3
# Akon          3
# Arijit        2
# Sonu Nigam    2
# Bruno         2
# Name: class, dtype: int64
